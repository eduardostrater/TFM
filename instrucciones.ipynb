# %% [markdown]
# **Instrucciones**
#
# Ejecutar principal.py
# Se le solicitará al usuario que ingrese una consulta.
#
# Ingresar por ejemplo: "Dame el promedio de la temperatura de la ciudad de Canta, Departamento de Lima, país Peru; durante el 1er semestre 2025"
